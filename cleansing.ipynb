# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/DATA QUALITY MANAGEMENT')

# %%
# %cd /content/drive/My Drive/Colab Notebooks/DATA QUALITY MANAGEMENT
# Out:
# /content/drive/My Drive/Colab Notebooks/DATA QUALITY MANAGEMENT

# %%
import pandas as pd
import numpy as np
import random
import string
import re
import pickle

# %% [markdown]
# #Load Dictionary and Trained Machine Learning Models

# %%
# Load Dictionary
dictionary = pd.read_excel('data_dict.xlsx')
dictionary
# Out:
#   model              model_name   meta data_type  \
# 0    DT  email_mlp_model.joblib  email    string
# 1    LR   name_mlp_model.joblib   name    string
#
#                                    invalid  valid
# 0  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}      1
# 1                      [^A-Za-z\s]+ \s{2,}      1

# %%
# Load Machine Learning Model and CountVectorizer Data (Email Model)
from joblib import load
#model email
email_validation_info  = dictionary[dictionary['meta'] == 'email']
invalid_email_regex    = email_validation_info['invalid'].values[0]
valid_email_regex      = email_validation_info['valid'].values[0]

# Load Model from File name
email_validation_model = email_validation_info['model_name'].values[0]
print("Load model from :", 'model/'+email_validation_model)
email_validation_model = load('model/'+email_validation_model)
email_validation_model
# Out:
# Load model from : model/email_mlp_model.joblib
# Pipeline(steps=[('vectorizer',
#                  CountVectorizer(analyzer='char', max_features=1000)),
#                 ('clf',
#                  MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=1000,
#                                random_state=42))])

# %%
# Load Machine Learning Model and CountVectorizer Data (Name Model)
from joblib import load

#model email
name_validation_info  = dictionary[dictionary['meta'] == 'name']

invalid_name_regex    = name_validation_info['invalid'].values[0]
valid_email_regex     = name_validation_info['valid'].values[0]

# Load Model from File name
name_validation_model   = name_validation_info['model_name'].values[0]
print("Load model from :", 'model/'+name_validation_model)
name_validation_model   = load('model/'+name_validation_model)
name_validation_model
# Out:
# Load model from : model/name_mlp_model.joblib
# Pipeline(steps=[('vectorizer',
#                  CountVectorizer(analyzer='char', max_features=1000)),
#                 ('clf',
#                  MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=1000,
#                                random_state=42))])

# %%
text = 'Alice?Brown'
prediction = name_validation_model.predict([text])
prediction
# Out:
# array([0])

# %%
# Cleaning Function
def cleaning_text_process(invalid_regex, text, replacment) :
  regex_patterns = invalid_regex.split(' ')
  regex_patterns = [re.compile(pattern) for pattern in regex_patterns]
  cleaned_string = text
  for pattern in regex_patterns:
      cleaned_string = pattern.sub(replacment, cleaned_string)
  cleaned_string = cleaned_string.strip()
  # print(cleaned_string)
  return cleaned_string

def predict_text(text, model) :
  prediction = model.predict([text])
  model = None
  return prediction

# Machine Learning Prediction Function
def predict_text_validity(text, model, invalid_regex, replacement):
    prediction = predict_text(text,  model)
    if prediction[0]:
      return [text, prediction[0], text, predict_text(text, model)[0]]
    else:
      return [text, prediction[0], cleaning_text_process(invalid_regex, text, replacement), predict_text(cleaning_text_process(invalid_regex, text, replacement), model)[0]]

# %% [markdown]
# #Prediction Function

# %% [markdown]
# # Test Using Excel Data

# %%
#Load Test Excel
testing = pd.read_excel('testing.xlsx')
testing
# Out:
#                   name                        email
# 0             John-Doe             john.doe@example
# 1       Jane Smith .Jr                  user@domain
# 2        Kirsya Mars1a            invalid-email.com
# 3            Kaido Ren               123@domain.com
# 4          Bob Johnson             user@domain..com
# 5          Alice?Brown      alice.brown@example.com
# 6        Robert&Miller           user123@domain.net
# 7          Emma Taylor  first.last@sub.domain.co.uk
# 8        William Clark      user_name123@company.io
# 9       Sarah 12Wilson  user+tag@email-provider.com
# 10          John Smith        john$mith@example.com
# 11       Alice Johnson    alice.johnson@example.com
# 12  Michael Brown .phd    michael#brown@example.com

# %%
column_names = testing.columns
input_data = []
status = []
output = []
final_status = []
meta = []
regex_pattern = []

# Dictionary
validation_models = {
    'email': ( email_validation_model, invalid_email_regex, ''),
    'name': (name_validation_model, invalid_name_regex, ' ')
}

for name in column_names:
    data = testing[name]
    for text in data:
        model, regex, replacement = validation_models[name]
        result = predict_text_validity(text, model, regex, replacement)
        input_data.append(result[0])
        status.append(result[1])
        output.append(result[2])
        final_status.append(result[3])
        meta.append(name)
        regex_pattern.append(regex if result[1] == 0 else '')

# %%
# Create DataFrame for results
result_df = pd.DataFrame({
    'Input': input_data,
    'Meta' : meta,
    'Status': status,
    'Output': output,
    'Final Status': final_status,
    'Regex Pattern': regex_pattern
})

result_df
# Out:
#                           Input   Meta  Status                       Output  \
# 0                      John-Doe   name       0                     John Doe
# 1                Jane Smith .Jr   name       0                Jane Smith Jr
# 2                 Kirsya Mars1a   name       0                Kirsya Mars a
# 3                     Kaido Ren   name       1                    Kaido Ren
# 4                   Bob Johnson   name       1                  Bob Johnson
# 5                   Alice?Brown   name       0                  Alice Brown
# 6                 Robert&Miller   name       0                Robert Miller
# 7                   Emma Taylor   name       1                  Emma Taylor
# 8                 William Clark   name       1                William Clark
# 9                Sarah 12Wilson   name       0                 Sarah Wilson
# 10                   John Smith   name       1                   John Smith
# 11                Alice Johnson   name       1                Alice Johnson
# 12           Michael Brown .phd   name       1           Michael Brown .phd
# 13             john.doe@example  email       1             john.doe@example
# 14                  user@domain  email       0                  user@domain
# 15            invalid-email.com  email       0            invalid-email.com
# 16               123@domain.com  email       1               123@domain.com
# 17             user@domain..com  email       1             user@domain..com
# 18      alice.brown@example.com  email       1      alice.brown@example.com
# 19           user123@domain.net  email       1           user123@domain.net
# 20  first.last@sub.domain.co.uk  email       1  first.last@sub.domain.co.uk
# 21      user_name123@company.io  email       1      user_name123@company.io
# 22  user+tag@email-provider.com  email       0   usertag@email-provider.com
# 23        john$mith@example.com  email       0         johnmith@example.com
# 24    alice.johnson@example.com  email       1    alice.johnson@example.com
# 25    michael#brown@example.com  email       0     michaelbrown@example.com
#
#     Final Status                            Regex Pattern
# 0              1                      [^A-Za-z\s]+ \s{2,}
# 1              1                      [^A-Za-z\s]+ \s{2,}
# 2              1                      [^A-Za-z\s]+ \s{2,}
# 3              1
# 4              1
# 5              1                      [^A-Za-z\s]+ \s{2,}
# 6              1                      [^A-Za-z\s]+ \s{2,}
# 7              1
# 8              1
# 9              1                      [^A-Za-z\s]+ \s{2,}
# 10             1
# 11             1
# 12             1
# 13             1
# 14             0  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}
# 15             0  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}
# 16             1
# 17             1
# 18             1
# 19             1
# 20             1
# 21             1
# 22             1  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}
# 23             1  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}
# 24             1
# 25             1  ^[^\w]+|[^\w]+$ [^a-zA-Z0-9_.@-] \s{2,}
